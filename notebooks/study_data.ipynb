# %% [markdown]
# # Import Data

# %%
# imports
import numpy as np
import pandas as pd

# %%
og_data = pd.read_pickle('../exports/dataframes/original_khuong_data.pkl')
mf_data = pd.read_pickle('../exports/dataframes/meanfield_khuong_data.pkl')

# %%
og_data
# Out:
#               params  steps  proportion_pellet  pickup_rate  drop_rate  volume
# 0     num_steps=5000      0              0.026     0.026000   0.000000       0
# 1     num_agents=500      1              0.050     0.024641   0.000000       0
# 2               m=15      2              0.070     0.021053   0.000000       0
# 3      lifetime=1000      3              0.102     0.036559   0.028571       1
# 4       runtime=717s      4              0.132     0.033408   0.000000       1
# ...              ...    ...                ...          ...        ...     ...
# 4995                   4995              0.198     0.002513   0.039216   16923
# 4996                   4996              0.188     0.004988   0.070707   16929
# 4997                   4997              0.186     0.004926   0.031915   16932
# 4998                   4998              0.186     0.002457   0.010753   16933
# 4999                   4999              0.182     0.004914   0.043011   16936
#
# [5000 rows x 6 columns]

# %%
mf_data
# Out:
#               params  steps  proportion_pellet  pickup_rate  drop_rate  \
# 0     num_steps=5000      0              0.026     0.026000   0.000000
# 1     num_agents=500      1              0.068     0.043121   0.000000
# 2      lifetime=1000      2              0.084     0.023605   0.088235
# 3       runtime=283s      3              0.112     0.034934   0.047619
# 4                         4              0.132     0.027027   0.035714
# ...              ...    ...                ...          ...        ...
# 4995                   4995              0.154     0.016317   0.014085
# 4996                   4996              0.154     0.002364   0.012987
# 4997                   4997              0.154     0.002364   0.012987
# 4998                   4998              0.156     0.004728   0.012987
# 4999                   4999              0.154     0.002370   0.025641
#
#       surface_area  volume
# 0            40013       0
# 1            40034       0
# 2            40069       3
# 3            40101       5
# 4            40129       7
# ...            ...     ...
# 4995        101026   17907
# 4996        101026   17908
# 4997        101029   17909
# 4998        101030   17910
# 4999        101031   17912
#
# [5000 rows x 7 columns]

# %% [markdown]
# # Plot Data

# %%
import matplotlib.pyplot as plt

# %%
# proportion pellet
plt.plot(og_data['steps'], og_data['proportion_pellet'], label="original")
plt.plot(mf_data['steps'], mf_data['proportion_pellet'], label="mean field")
plt.legend()

# %%
# pickup rate
plt.plot(og_data['steps'], og_data['pickup_rate'], label="original")
plt.plot(mf_data['steps'], mf_data['pickup_rate'], label="mean field")
plt.legend()

# %%
# drop rate
plt.plot(og_data['steps'], og_data['drop_rate'], label="original")
plt.plot(mf_data['steps'], mf_data['drop_rate'], label="mean field")
plt.legend()

# %%
# proportion floor
plt.plot(og_data['steps'], og_data['volume'], label="original")
plt.plot(mf_data['steps'], mf_data['volume'], label="mean field")
plt.legend()
