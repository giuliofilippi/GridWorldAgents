# %% [markdown]
# # Import Data

# %%
# imports
import numpy as np
import pandas as pd

# %%
og_data = pd.read_pickle('../exports_data/original_khuong_data.pkl')
mk_data = pd.read_pickle('../exports_data/markov_khuong_data.pkl')
mf_data = pd.read_pickle('../exports_data/mean_field_khuong_data.pkl')

# %%
og_data
# Out:
#                           params  steps  proportion pellet  \
# 0                 num_steps=1800      0              0.022
# 1                 num_agents=500      1              0.056
# 2                            m=4      2              0.088
# 3                  lifetime=1200      3              0.124
# 4     runtime=431.01873111724854      4              0.148
# ...                          ...    ...                ...
# 1795                               1795              0.448
# 1796                               1796              0.460
# 1797                               1797              0.456
# 1798                               1798              0.456
# 1799                               1799              0.456
#
#       proportion on floor  volume
# 0                   1.000       0
# 1                   0.996       0
# 2                   0.986       0
# 3                   0.990       0
# 4                   0.984       0
# ...                   ...     ...
# 1795                0.300    8623
# 1796                0.308    8625
# 1797                0.286    8629
# 1798                0.282    8632
# 1799                0.286    8633
#
# [1800 rows x 5 columns]

# %%
mk_data
# Out:
#                          params  steps  proportion pellet  proportion floor  \
# 0                num_steps=1800      0              0.028             1.000
# 1                num_agents=500      1              0.050             0.988
# 2                           m=4      2              0.082             0.994
# 3                 lifetime=1200      3              0.112             0.990
# 4     runtime=2078.199999809265      4              0.134             0.980
# ...                         ...    ...                ...               ...
# 1795                              1795              0.190             0.366
# 1796                              1796              0.186             0.350
# 1797                              1797              0.182             0.368
# 1798                              1798              0.174             0.362
# 1799                              1799              0.182             0.364
#
#       surface area  volume
# 0            40014       0
# 1            40025       0
# 2            40041       0
# 3            40074       0
# 4            40085       0
# ...            ...     ...
# 1795         78574       0
# 1796         78599       0
# 1797         78607       0
# 1798         78647       0
# 1799         78651       0
#
# [1800 rows x 6 columns]

# %%
mf_data
# Out:
#                           params  steps  proportion pellet  proportion floor  \
# 0                 num_steps=1800      0              0.018             1.000
# 1                 num_agents=500      1              0.048             1.000
# 2                  lifetime=1200      2              0.070             1.000
# 3     runtime=144.14990425109863      3              0.092             0.998
# 4                                     4              0.130             0.998
# ...                          ...    ...                ...               ...
# 1795                               1795              0.138             0.384
# 1796                               1796              0.136             0.344
# 1797                               1797              0.136             0.342
# 1798                               1798              0.132             0.346
# 1799                               1799              0.132             0.336
#
#       surface area  volume
# 0            40009       0
# 1            40024       0
# 2            40035       0
# 3            40046       0
# 4            40065       0
# ...            ...     ...
# 1795         79100   10408
# 1796         79116   10411
# 1797         79126   10415
# 1798         79136   10420
# 1799         79148   10423
#
# [1800 rows x 6 columns]

# %% [markdown]
# # Plot Data

# %%
import matplotlib.pyplot as plt

# %%
# proportion pellet
plt.plot(og_data['steps'], og_data['proportion pellet'], label="original")
plt.plot(mk_data['steps'], mk_data['proportion pellet'], label="markov")
plt.plot(mf_data['steps'], mf_data['proportion pellet'], label="mean field")
plt.legend()

# %%
# proportion floor
plt.plot(og_data['steps'], og_data['proportion on floor'], label="original")
plt.plot(mk_data['steps'], mk_data['proportion floor'], label="markov")
plt.plot(mf_data['steps'], mf_data['proportion floor'], label="mean field")
plt.legend()

# %%
# proportion floor
plt.plot(og_data['steps'], og_data['volume'], label="original")
plt.plot(mk_data['steps'], mk_data['volume'], label="markov")
plt.plot(mf_data['steps'], mf_data['volume'], label="mean field")
plt.legend()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
