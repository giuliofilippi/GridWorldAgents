# %% [markdown]
# # Import Data

# %%
# imports
import numpy as np
import pandas as pd

# %%
og_data = pd.read_pickle('../exports_data/original_khuong_data.pkl')
mk_data = pd.read_pickle('../exports_data/markov_khuong_data.pkl')
mf_data = pd.read_pickle('../exports_data/mean_field_khuong_data.pkl')

# %%
og_data
# Out:
#              params  steps  proportion pellet  proportion floor  volume
# 0    num_steps=1000      0              0.030             1.000       0
# 1    num_agents=500      1              0.054             0.988       0
# 2               m=6      2              0.080             0.996       0
# 3     lifetime=1200      3              0.104             0.994       1
# 4      runtime=160s      4              0.114             0.992       1
# ..              ...    ...                ...               ...     ...
# 995                    995              0.494             0.318    5079
# 996                    996              0.492             0.298    5080
# 997                    997              0.498             0.348    5084
# 998                    998              0.500             0.312    5087
# 999                    999              0.494             0.324    5091
#
# [1000 rows x 5 columns]

# %%
mk_data
# Out:
#              params  steps  proportion pellet  proportion floor  surface area  \
# 0    num_steps=1000      0              0.030             1.000         40015
# 1    num_agents=500      1              0.062             0.992         40040
# 2               m=6      2              0.096             0.992         40066
# 3     lifetime=1200      3              0.120             0.994         40078
# 4      runtime=687s      4              0.138             0.986         40096
# ..              ...    ...                ...               ...           ...
# 995                    995              0.184             0.472         68459
# 996                    996              0.184             0.436         68485
# 997                    997              0.184             0.458         68507
# 998                    998              0.188             0.468         68515
# 999                    999              0.194             0.442         68523
#
#      volume
# 0         0
# 1         1
# 2         2
# 3         2
# 4         3
# ..      ...
# 995    5969
# 996    5974
# 997    5981
# 998    5984
# 999    5985
#
# [1000 rows x 6 columns]

# %%
mf_data
# Out:
#              params  steps  proportion pellet  proportion floor  surface area  \
# 0    num_steps=1000      0              0.018             1.000         40009
# 1    num_agents=500      1              0.050             1.000         40025
# 2     lifetime=1200      2              0.072             1.000         40045
# 3       runtime=27s      3              0.104             1.000         40079
# 4                        4              0.138             0.998         40114
# ..              ...    ...                ...               ...           ...
# 995                    995              0.208             0.466         68584
# 996                    996              0.202             0.476         68591
# 997                    997              0.196             0.470         68609
# 998                    998              0.202             0.476         68620
# 999                    999              0.198             0.492         68649
#
#      volume
# 0         0
# 1         0
# 2         1
# 3         3
# 4         5
# ..      ...
# 995    6504
# 996    6508
# 997    6515
# 998    6518
# 999    6525
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Plot Data

# %%
import matplotlib.pyplot as plt

# %%
# proportion pellet
plt.plot(og_data['steps'], og_data['proportion pellet'], label="original")
plt.plot(mk_data['steps'], mk_data['proportion pellet'], label="markov")
plt.plot(mf_data['steps'], mf_data['proportion pellet'], label="mean field")
plt.legend()

# %%
# proportion floor
plt.plot(og_data['steps'], og_data['proportion floor'], label="original")
plt.plot(mk_data['steps'], mk_data['proportion floor'], label="markov")
plt.plot(mf_data['steps'], mf_data['proportion floor'], label="mean field")
plt.legend()

# %%
# proportion floor
plt.plot(og_data['steps'], og_data['volume'], label="original")
plt.plot(mk_data['steps'], mk_data['volume'], label="markov")
plt.plot(mf_data['steps'], mf_data['volume'], label="mean field")
plt.legend()
