# %% [markdown]
# # Import Data

# %%
# imports
import numpy as np
import pandas as pd

# %%
og_data = pd.read_pickle('../exports_data/original_khuong_data.pkl')
mk_data = pd.read_pickle('../exports_data/markov_khuong_data.pkl')
mf_data = pd.read_pickle('../exports_data/mean_field_khuong_data.pkl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-6c91ef0c3953> in <module>
# ----> 1 og_data = pd.read_pickle('../exports_data/original_khuong_data.pkl')
#       2 mk_data = pd.read_pickle('../exports_data/markov_khuong_data.pkl')
#       3 mf_data = pd.read_pickle('../exports_data/mean_field_khuong_data.pkl')
#
# ~/anaconda3/envs/antworld/lib/python3.6/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression)
#     180                 # We want to silence any warnings about, e.g. moved modules.
#     181                 warnings.simplefilter("ignore", Warning)
# --> 182                 return pickle.load(f)
#     183         except excs_to_catch:
#     184             # e.g.
#
# ValueError: unsupported pickle protocol: 5

# %%
og_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f6012dfe9473> in <module>
# ----> 1 og_data
#
# NameError: name 'og_data' is not defined

# %%
mk_data
# Out:
#              params  steps  proportion pellet  proportion floor  surface area  \
# 0    num_steps=1000      0              0.030             1.000         40015
# 1    num_agents=500      1              0.050             0.994         40025
# 2               m=6      2              0.072             0.992         40036
# 3     lifetime=1200      3              0.086             0.988         40052
# 4     runtime=1002s      4              0.096             0.992         40066
# ..              ...    ...                ...               ...           ...
# 995                    995              0.232             0.490         68692
# 996                    996              0.232             0.482         68716
# 997                    997              0.228             0.480         68724
# 998                    998              0.234             0.456         68742
# 999                    999              0.234             0.444         68770
#
#      volume
# 0         0
# ...

# %%
mf_data
# Out:
#              params  steps  proportion pellet  proportion floor  surface area  \
# 0    num_steps=1000      0              0.018             1.000         40009
# 1    num_agents=500      1              0.052             1.000         40026
# 2     lifetime=1200      2              0.064             0.998         40050
# 3       runtime=44s      3              0.092             1.000         40064
# 4                        4              0.108             0.994         40090
# ..              ...    ...                ...               ...           ...
# 995                    995              0.170             0.466         68418
# 996                    996              0.164             0.448         68420
# 997                    997              0.168             0.456         68431
# 998                    998              0.166             0.472         68450
# 999                    999              0.172             0.450         68476
#
#      volume
# 0         0
# ...

# %% [markdown]
# # Plot Data

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(mf_data['steps'], mf_data['proportion pellet'], label="mean field")

# %%
# proportion pellet
plt.plot(og_data['steps'], og_data['proportion pellet'], label="original")
plt.plot(mk_data['steps'], mk_data['proportion pellet'], label="markov")
plt.plot(mf_data['steps'], mf_data['proportion pellet'], label="mean field")
plt.legend()

# %%
# proportion floor
plt.plot(og_data['steps'], og_data['proportion floor'], label="original")
plt.plot(mk_data['steps'], mk_data['proportion floor'], label="markov")
plt.plot(mf_data['steps'], mf_data['proportion floor'], label="mean field")
plt.legend()

# %%
# proportion floor
plt.plot(og_data['steps'], og_data['volume'], label="original")
plt.plot(mk_data['steps'], mk_data['volume'], label="markov")
plt.plot(mf_data['steps'], mf_data['volume'], label="mean field")
plt.legend()
